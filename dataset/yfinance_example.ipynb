# %%
import yfinance as yf

# %%
yf.download("^FTSE", interval="1d", start_date="2020-07-15", end_date="2020-07-18")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1984-01-03   997.500000  1001.400024   997.500000   997.500000   997.500000
# 1984-01-04   997.500000   999.500000   993.299988   998.599976   998.599976
# 1984-01-05  1007.099976  1015.799988  1007.099976  1015.799988  1015.799988
# 1984-01-06  1019.000000  1029.300049  1019.000000  1029.000000  1029.000000
# 1984-01-09  1030.599976  1035.400024  1030.599976  1034.599976  1034.599976
# ...                 ...          ...          ...          ...          ...
# 2020-07-13  6095.399902  6187.299805  6095.399902  6176.200195  6176.200195
# 2020-07-14  6176.200195  6179.799805  6093.200195  6179.799805  6179.799805
# 2020-07-15  6179.799805  6323.600098  6179.799805  6292.700195  6292.700195
# 2020-07-16  6292.700195  6296.799805  6227.299805  6250.700195  6250.700195
# ...

# %% [markdown]
# ---
# ### Microsoft

# %%
msft = yf.Ticker("MSFT")

# %%
hist = msft.history(period="max")
hist
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-07-10  213.62  214.08  211.08  213.67    26177600        0.0
# 2020-07-13  214.48  215.80  206.50  207.07    38135600        0.0
# 2020-07-14  206.13  208.85  202.03  208.35    37591800        0.0
# 2020-07-15  209.56  211.33  205.03  208.04    32144500        0.0
# 2020-07-16  205.40  205.70  203.29  204.30     7666156        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
msft.get_balance_sheet()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show financials
msft.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.get_institutional_holders(start="2018-07-01")
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  640172572    2020-03-30  0.0844
# 1                     Blackrock Inc.  517578906    2020-03-30  0.0683
# 2           State Street Corporation  314771248    2020-03-30  0.0415
# 3                           FMR, LLC  237892832    2020-03-30  0.0314
# 4      Price (T.Rowe) Associates Inc  172056401    2020-03-30  0.0227
# 5            Capital World Investors  139116236    2020-03-30  0.0183
# 6      Geode Capital Management, LLC  115684966    2020-03-30  0.0153
# 7    Capital International Investors  103523946    2020-03-30  0.0137
# 8  Capital Research Global Investors   93247848    2020-03-30  0.0123
# 9         Northern Trust Corporation   92119080    2020-03-30  0.0121
#
#           Value
# 0  100961616330
# 1   81627369265
# 2   49642573522
# 3   37518078534
# 4   27135015001
# 5   21940021579
# 6   18244675987
# 7   16326761523
# 8   14706118108
# 9   14528100106

# %%
# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2020-05-18 13:45:46     RBC Capital     Outperform              reit
# 2020-06-24 13:30:12  Argus Research            Buy              main
# 2020-06-24 13:58:07   Goldman Sachs            Buy              main
# 2020-07-09 10:31:04         Wedbush     Outperform              main
# 2020-07-09 12:39:10  Morgan Stanley     Overweight              main
#
# [274 rows x 4 columns]

# %%
# show next event (earnings, etc)
msft.calendar
# Out:
#                                 Value
# Earnings Date     2020-07-22 00:00:00
# Earnings Average                 1.38
# Earnings Low                     1.28
# Earnings High                    1.51
# Revenue Average           36491800000
# Revenue Low               36053000000
# Revenue High              37098000000

# %%
pd.DataFrame([msft.info])
# Out:
#      zip      sector  fullTimeEmployees  \
# 0  98052  Technology             144000
#
#                                  longBusinessSummary     city         phone  \
# 0  Microsoft Corporation develops, licenses, and ...  Redmond  425-882-8080
#
#   state        country companyOfficers                   website  maxAge  \
# 0    WA  United States              []  http://www.microsoft.com       1
#
#             address1           fax                 industry  previousClose  \
# 0  One Microsoft Way  425-706-7329  Software—Infrastructure         208.04
#
#    regularMarketOpen  twoHundredDayAverage  trailingAnnualDividendYield  \
# 0              205.4              175.4846                     0.009565
#
#    payoutRatio volume24Hr  regularMarketDayHigh navPrice  \
# 0       0.3233       None                 205.7     None
#
#    averageDailyVolume10Day totalAssets  regularMarketPreviousClose  \
# 0                 33283687        None                      208.04
#
# ...

# %%
pd.DataFrame([msft.info])
# Out:
#      zip      sector  fullTimeEmployees  \
# 0  98052  Technology             144000
#
#                                  longBusinessSummary     city         phone  \
# 0  Microsoft Corporation develops, licenses, and ...  Redmond  425-882-8080
#
#   state        country companyOfficers                   website  maxAge  \
# 0    WA  United States              []  http://www.microsoft.com       1
#
#             address1           fax                 industry  previousClose  \
# 0  One Microsoft Way  425-706-7329  Software—Infrastructure         214.32
#
#    regularMarketOpen  twoHundredDayAverage  trailingAnnualDividendYield  \
# 0             213.62             174.40102                     0.009285
#
#    payoutRatio volume24Hr  regularMarketDayHigh navPrice  \
# 0       0.3233       None                214.08     None
#
#    averageDailyVolume10Day totalAssets  regularMarketPreviousClose  \
# 0                 31392385        None                      214.32
#
# ...

# %% [markdown]
# ---
# ### TOYOTA

# %%
toyota = yf.Ticker("TM")

# %%
toyota.history(period="max")
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2000-01-04  2732.84  2742.14  2621.30  2621.30    51900        0.0
# 2000-01-05  2742.14  2881.57  2677.07  2714.25    99900        0.0
# 2000-01-06  2742.14  2742.14  2658.48  2677.07    63500        0.0
# 2000-01-07  2686.37  2770.02  2677.07  2704.96    56000        0.0
# 2000-01-10  2704.96  2704.96  2704.96  2704.96        0        0.0
# ...             ...      ...      ...      ...      ...        ...
# 2020-07-13  2386.50  2468.00  2375.00  2461.50  3751100        0.0
# 2020-07-14  2427.50  2440.50  2408.50  2422.00  2064700        0.0
# 2020-07-15  2479.50  2494.50  2425.00  2445.00  2316100        0.0
# 2020-07-16  2500.00  2613.50  2500.00  2571.00  6433200        0.0
# 2020-07-17  2525.00  2549.00  2462.50  2477.50  3267300        0.0
#
#             Stock Splits
# Date
# 2000-01-04           0.0
# 2000-01-05           0.0
# 2000-01-06           0.0
# 2000-01-07           0.0
# ...

# %%
toyota.get_balance_sheet()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
toyota.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
toyota.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
toyota.get_institutional_holders()
# Out:
#                                               Holder   Shares Date Reported  \
# 0  Vanguard International Stock Index-Total Intl ...  1944180    2020-04-30
# 1           iShares MSCI EAFE Minimum Volatility ETF  1903100    2020-04-30
# 2  Vanguard Tax Managed Fund-Vanguard Developed M...   718631    2020-03-31
# 3             Old Westbury Large Cap Strategies Fund   457505    2020-04-30
# 4                              iShares MSCI Eafe ETF   431600    2020-04-30
# 5                         iShares Core MSCI EAFE ETF   424800    2020-04-30
# 6  Fidelity SAI International Low Volatility Inde...   394300    2020-04-30
# 7                             iShares MSCI Japan ETF   337700    2020-04-30
# 8               iShares Edge MSCI Min Vol Global ETF   277200    2020-04-30
# 9                  Fidelity International Index Fund   224500    2020-04-30
#
#     % Out       Value
# 0  0.0056  4473558180
# 1  0.0055  4379033100
# 2  0.0021  1896467209
# 3  0.0013  1052719005
# ...

# %%
toyota.get_recommendations()
# Out:
#                                  Firm      To Grade    From Grade Action
# Date
# 2012-02-17 06:15:00        Oxen Group          Hold                 init
# 2012-11-05 12:21:00     Credit Suisse    Outperform       Neutral     up
# 2013-01-10 16:25:47   Bank of America           Buy                   up
# 2013-01-15 10:42:09         Citigroup           Buy       Neutral     up
# 2013-02-07 14:39:56     Goldman Sachs           Buy       Neutral     up
# 2013-08-06 09:49:19   Mito Securities    Outperform       Neutral     up
# 2013-10-21 09:30:33          Barclays    Overweight                 init
# 2013-11-21 06:21:42         Jefferies          Hold                 init
# 2014-01-28 16:00:00               UBS           Buy                 init
# 2014-02-25 08:00:00         JP Morgan       Neutral                 init
# 2014-04-11 08:00:00            Mizuho           Buy       Neutral     up
# 2014-04-22 08:00:00    Mitsubishi UFJ       Neutral    Outperform   down
# ...

# %%
pd.DataFrame([toyota.info], index=pd.DatetimeIndex([datetime.date.today()]))
# Out:
#                  zip       sector  \
# 2020-07-18  105-7140  Industrials
#
#                                           longBusinessSummary   city  \
# 2020-07-18  ANA Holdings Inc., together with its subsidiar...  Tokyo
#
#                      phone country companyOfficers               website  \
# 2020-07-18  81 3 6735 1001   Japan              []  http://www.ana.co.jp
#
#             maxAge              address1  industry  \
# 2020-07-18       1  Shiodome City Center  Airlines
#
#                                       address2  previousClose  \
# 2020-07-18  1-5-2, Higashi-Shimbashi Minato-ku           2571
#
#             regularMarketOpen  twoHundredDayAverage  \
# 2020-07-18               2525             2821.5703
#
#             trailingAnnualDividendYield  payoutRatio volume24Hr  \
# 2020-07-18                     0.029172       0.2776       None
#
#             regularMarketDayHigh navPrice  averageDailyVolume10Day  \
# ...

# %%
pd.DatetimeIndex([datetime.date.today()], name="hoge")
# Out:
# DatetimeIndex(['2020-07-18'], dtype='datetime64[ns]', name='hoge', freq=None)

# %% [markdown]
# ---

# %%
# start<= day < end でダウンロード
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "OCDO.L",
        interval = "1m",
        start = "2020-07-14",
        end = "2020-07-16"
    )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                                   Open         High         Low       Close  \
# Datetime
# 2020-07-13 16:00:00+01:00  2032.900024  2032.900024  2031.00000  2031.00000
# 2020-07-13 16:01:00+01:00  2031.000000  2031.000000  2029.00000  2029.00000
# 2020-07-13 16:02:00+01:00  2028.000000  2028.000000  2028.00000  2028.00000
# 2020-07-13 16:03:00+01:00  2029.000000  2029.000000  2029.00000  2029.00000
# 2020-07-13 16:04:00+01:00  2028.104980  2028.104980  2028.10498  2028.10498
#
#                             Adj Close  Volume
# Datetime
# 2020-07-13 16:00:00+01:00  2031.00000       0
# 2020-07-13 16:01:00+01:00  2029.00000    5399
# 2020-07-13 16:02:00+01:00  2028.00000    3571
# 2020-07-13 16:03:00+01:00  2029.00000    2336
# 2020-07-13 16:04:00+01:00  2028.10498    1148

# %%
timezone = data.index.tz

# %%
data.index = data.index.tz_localize(None)

# %%
data.loc[data.index.date[0]:]
# Out:
#                       Open   High    Low  Close  Adj Close  Volume
# Datetime
# 2020-07-14 10:11:00  2.100  2.100  2.100  2.100      2.100       0
# 2020-07-14 10:12:00  2.105  2.105  2.100  2.100      2.100   11497
# 2020-07-14 10:13:00  2.100  2.105  2.100  2.100      2.100   21511
# 2020-07-14 10:14:00  2.100  2.110  2.100  2.100      2.100   15506
# 2020-07-14 10:15:00  2.105  2.105  2.105  2.105      2.105     254
# ...                    ...    ...    ...    ...        ...     ...
# 2020-07-15 15:55:00  2.140  2.140  2.135  2.140      2.140  224174
# 2020-07-15 15:56:00  2.135  2.140  2.135  2.135      2.135  226254
# 2020-07-15 15:57:00  2.140  2.140  2.135  2.140      2.140  239412
# 2020-07-15 15:58:00  2.140  2.140  2.140  2.140      2.140    1818
# 2020-07-15 15:59:00  2.140  2.140  2.140  2.140      2.140       0
#
# [570 rows x 6 columns]

# %%
data.index.tz_localize(timezone)
# Out:
# DatetimeIndex(['2020-07-14 09:00:00+09:00', '2020-07-14 09:01:00+09:00',
#                '2020-07-14 09:02:00+09:00', '2020-07-14 09:03:00+09:00',
#                '2020-07-14 09:04:00+09:00', '2020-07-14 09:05:00+09:00',
#                '2020-07-14 09:06:00+09:00', '2020-07-14 09:07:00+09:00',
#                '2020-07-14 09:08:00+09:00', '2020-07-14 09:11:00+09:00',
#                ...
#                '2020-07-15 14:50:00+09:00', '2020-07-15 14:51:00+09:00',
#                '2020-07-15 14:52:00+09:00', '2020-07-15 14:53:00+09:00',
#                '2020-07-15 14:54:00+09:00', '2020-07-15 14:55:00+09:00',
#                '2020-07-15 14:56:00+09:00', '2020-07-15 14:57:00+09:00',
#                '2020-07-15 14:58:00+09:00', '2020-07-15 14:59:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', name='Datetime', length=713, freq=None)

# %% [markdown]
# ---
# ### GOLD

# %%
gold = yf.Ticker("GC=F")

# %%
gold.info
# Out:
# {'previousClose': 1800.3,
#  'regularMarketOpen': 1796.9,
#  'twoHundredDayAverage': 1669.255,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 1813.9,
#  'navPrice': None,
#  'averageDailyVolume10Day': 35855095,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 1800.3,
#  'fiftyDayAverage': 1762.721,
#  'trailingAnnualDividendRate': None,
#  'open': 1796.9,
#  'toCurrency': None,
#  'averageVolume10days': 35855095,
#  'expireDate': 1598486400,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 1795.2,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 162684,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': 289325,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 30581009,
# ...

# %%
data = gold.history(
        start = "2020-07-03",
        end = "2020-07-03",
        interval="1d")

# %%
data.index.tz

# %% [markdown]
# ---
# ### Tickers

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "^FTSE",
        start = "2020-07-01",
        end = "2020-07-03",
        interval="1d"
    )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                    Open         High     Low        Close    Adj Close  \
# Date
# 2020-06-30  6225.799805  6237.500000  6147.0  6169.700195  6169.700195
# 2020-07-01  6169.700195  6202.000000  6084.5  6158.000000  6158.000000
# 2020-07-02  6158.000000  6258.600098  6158.0  6240.399902  6240.399902
#
#                Volume
# Date
# 2020-06-30  827284200
# 2020-07-01  724502100
# 2020-07-02  806189500

# %% [markdown]
# ---
# ### FX

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "USDJPY=X EURUSD=X AUDUSD=X GBPUSD=X",
        start = "2020-07-10",
        end = "2020-07-13",
    )
# Out:
# [*********************100%***********************]  4 of 4 completed
#
# 1 Failed download:
# - USDJPY=1: No data found, symbol may be delisted

# %%
data
# Out:
#            Adj Close                                  Close            \
#             AUDUSD=X  EURUSD=X  GBPUSD=X USDJPY=1  AUDUSD=X  EURUSD=X
# Date
# 2020-07-09  0.698910  1.133915  1.261352      NaN  0.698910  1.133915
# 2020-07-10  0.695894  1.128796  1.260509      NaN  0.695894  1.128796
#
#                                    High                               \
#             GBPUSD=X USDJPY=1  AUDUSD=X  EURUSD=X  GBPUSD=X USDJPY=1
# Date
# 2020-07-09  1.261352      NaN  0.700202  1.137268  1.266945      NaN
# 2020-07-10  1.260509      NaN  0.696772  1.132477  1.266400      NaN
#
#                  Low                                   Open            \
#             AUDUSD=X  EURUSD=X  GBPUSD=X USDJPY=1  AUDUSD=X  EURUSD=X
# Date
# 2020-07-09  0.695159  1.128796  1.260224      NaN  0.698529  1.133787
# 2020-07-10  0.692468  1.125720  1.256913      NaN  0.696282  1.128923
#
#                                 Volume
# ...

# %% [markdown]
# ---
# ## Plyaground

# %%
yfTicker = yf.Ticker("KALU")

# %%
df = yfTicker.history(period="7d", interval="1m")

# %%
yfTicker.info
# Out:
# {'zip': '92610-2831',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 2820,
# ...

# %%
timezone = df.index.tz  # timezone一時保存
df.index = df.index.tz_localize(None)

# %%
yfTicker.history(start="2020-07-17", end="2020-07-19", interval="1m").index
# Out:
# DatetimeIndex(['2020-07-16 16:06:00+01:00', '2020-07-16 16:07:00+01:00',
#                '2020-07-16 16:08:00+01:00', '2020-07-16 16:09:00+01:00',
#                '2020-07-16 16:10:00+01:00', '2020-07-16 16:11:00+01:00',
#                '2020-07-16 16:12:00+01:00', '2020-07-16 16:13:00+01:00',
#                '2020-07-16 16:14:00+01:00', '2020-07-16 16:15:00+01:00',
#                ...
#                '2020-07-17 16:20:00+01:00', '2020-07-17 16:21:00+01:00',
#                '2020-07-17 16:22:00+01:00', '2020-07-17 16:23:00+01:00',
#                '2020-07-17 16:24:00+01:00', '2020-07-17 16:25:00+01:00',
#                '2020-07-17 16:26:00+01:00', '2020-07-17 16:27:00+01:00',
#                '2020-07-17 16:28:00+01:00', '2020-07-17 16:29:00+01:00'],
#               dtype='datetime64[ns, Europe/London]', name='Datetime', length=446, freq=None)
