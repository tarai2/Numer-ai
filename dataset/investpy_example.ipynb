# %%
import investpy

# %%
# countries
investpy.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'dubai',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'euro zone',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'israeli',
#  'italy',
#  'ivory coast',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'kuwaiti',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestine',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Currency Index

# %%
investpy.

# %% [markdown]
# # Stock Index

# %% [markdown]
# ---
# ### US

# %%
investpy.indices.get_indices(country="united states")
# Out:
#             country                                        name  \
# 0     united states                         NQ US Mid Cap Value
# 1     united states                        NQ US Mid Cap Growth
# 2     united states  NQ US Mid Cap Telecommunications Equipment
# 3     united states                NQ US Mid Cap Semiconductors
# 4     united states             NQ US Mid Cap Computer Hardware
# ...             ...                                         ...
# 1373  united states                                 DJ Internet
# 1374  united states                     DJ Integrated Oil & Gas
# 1375  united states                        DJ Insurance Brokers
# 1376  united states           NQ OMX Green Economy ex-US TR USD
# 1377  united states               DJ Global ex-U.S. Select REIT
#
#                                            full_name     symbol currency  \
# 0                            NASDAQ US Mid Cap Value     NQUSMV      USD
# ...

# %%
df = investpy.indices.get_indices(country="united states")

# %%
df[df.name.str.contains("US Dollar")]
# Out:
#            country             name        full_name symbol currency  \
# 696  united states  US Dollar Index  US Dollar Index    DXY      USD
#
#              class         market
# 696  other_indices  world_indices

# %% [markdown]
# ---
# ### JP

# %%
investpy.indices.get_indices(country="japan")
# Out:
#     country                                    name  \
# 0     japan       TSE TOPIX17 Wholesale Stock Price
# 1     japan                             TOPIX Banks
# 2     japan  TSE TOPIX17 Transportation Stock Price
# 3     japan                TOPIX Air Transportation
# 4     japan           TSE TOPIX17 Steel Stock Price
# ..      ...                                     ...
# 239   japan                      N500 Railway & Bus
# 240   japan                       N500 Pulp & Paper
# 241   japan                       N500 Shipbuilding
# 242   japan              N500 Precision Instruments
# 243   japan                    N500 Pharmaceuticals
#
#                                        full_name    symbol currency  \
# 0         Tokyo SE TOPIX17 Wholesale Stock Price  TRAD17.T      JPY
# 1                                    TOPIX Banks   IBNKS.T      JPY
# 2    Tokyo SE TOPIX17 Transportation Stock Price  TRAN17.T      JPY
# ...

# %%
names = investpy.indices.get_indices(country="japan").name

# %%
names[names.str.contains("TOPIX17")].reset_index(drop=True)
# Out:
# 0            TSE TOPIX17 Wholesale Stock Price
# 1       TSE TOPIX17 Transportation Stock Price
# 2                TSE TOPIX17 Steel Stock Price
# 3          TSE TOPIX17 IT Services Stock Price
# 4          TSE TOPIX17 Real Estate Stock Price
# 5            TSE TOPIX17 Power Gas Stock Price
# 6        TSE TOPIX17 Pharmacetical Stock Price
# 7            TSE TOPIX17 Machinery Stock Price
# 8                 TSE TOPIX17 Food Stock Price
# 9               TSE TOPIX17 Retail Stock Price
# 10          TSE TOPIX17 Financials Stock Price
# 11    TSE TOPIX17 Energy Resources Stock Price
# 12        TSE TOPIX17 Construction Stock Price
# 13            TSE TOPIX17 Electric Stock Price
# 14               TSE TOPIX17 Banks Stock Price
# 15           TSE TOPIX17 Chemicals Stock Price
# 16          TSE TOPIX17 Automobile Stock Price
# Name: name, dtype: object

# %%
names[names.str.contains("JPY")]
# Out:
# 96             MSCI Japan Net JPY
# 100      MSCI Japan Mid Price JPY
# 108    MSCI Japan Large Price JPY
# 112         NQ AlphaDEX Japan JPY
# 115          MSCI Japan Price JPY
# 183                MSCI Japan JPY
# Name: name, dtype: object

# %% [markdown]
# ---
# ### UK

# %%
investpy.indices.get_indices(country="united kingdom")
# Out:
#             country                                name  \
# 0    united kingdom           FTSE 100 Minimum Variance
# 1    united kingdom         Stoxx UK 50 Risk 20% RV EUR
# 2    united kingdom         Stoxx UK 50 Risk 20% RV USD
# 3    united kingdom         Stoxx UK 50 Risk 15% RV EUR
# 4    united kingdom         Stoxx UK 50 Risk 15% RV USD
# ..              ...                                 ...
# 263  united kingdom                    FTSE 350 Telecom
# 264  united kingdom             FTSE 350 Life Insurance
# 265  united kingdom  FTSE 350 Industrial Transportation
# 266  united kingdom                     FTSE 350 Retail
# 267  united kingdom     FTSE 350 Industrial Engineering
#
#                               full_name     symbol currency            class  \
# 0             FTSE 100 Minimum Variance    FTUKXMV      GBP    other_indices
# 1           Stoxx UK 50 Risk 20% RV EUR   SUKR20EG      EUR    other_indices
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### **Search

# %%
res = investpy.search(text="Investing.com Euro Index(inveur)")

# %%
len(res)
# Out:
# 1

# %%
res[0].name
# Out:
# 'Investing.com Euro Index'

# %%
res[0].country
# Out:
# 'europe'

# %%
res[0].pair_type
# Out:
# 'indice'

# %%
res[0].retrieve_historical_data(from_date='01/01/2019',to_date='01/01/2020')
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2019-01-01  92.81  92.96  91.84  92.78       0
# 2019-01-02  92.78  92.94  91.14  92.51       0
# 2019-01-03  92.51  93.04  91.35  92.53       0
# 2019-01-04  92.53  93.06  91.42  91.65       0
# 2019-01-06  91.67  91.79  91.65  91.78       0
# ...           ...    ...    ...    ...     ...
# 2019-12-27  96.29  97.00  96.12  96.68       0
# 2019-12-29  96.18  96.72  96.18  96.69       0
# 2019-12-30  96.69  96.88  96.63  96.76       0
# 2019-12-31  96.74  96.93  96.69  96.79       0
# 2020-01-01  96.79  97.01  96.71  96.86       0
#
# [313 rows x 5 columns]

# %% [markdown]
# ---

# %%
df = pd.DataFrame([[1,1], [2,2], [3,3]])

# %%
df.to_hdf("test.hdf", key="pandasdf")

# %%
pd.read_hdf("test.hdf", start=-1)
# Out:
#    0  1
# 2  3  3
