# %%
import investpy

# %%
# countries
investpy.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'dubai',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'euro zone',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'israeli',
#  'italy',
#  'ivory coast',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'kuwaiti',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestine',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Currency Index

# %%
df = investpy.indices.get_index_historical_data(index="US Dollar Index",
                                                country="united states",
                                                from_date="01/07/2020",
                                                to_date="10/07/2020")
df.head()
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2020-07-01  97.39  97.62  97.03  97.20       0      USD
# 2020-07-02  97.14  97.34  96.81  97.32       0      USD
# 2020-07-03  97.21  97.36  97.12  97.17       0      USD
# 2020-07-06  97.15  97.19  96.57  96.72       0      USD
# 2020-07-07  96.75  97.15  96.60  96.88       0      USD

# %% [markdown]
# # Stock Index

# %%
investpy.indices.get_index_countries()[:5]
# Out:
# ['argentina', 'australia', 'austria', 'bahrain', 'bangladesh']

# %%
indice_name = {}

# %% [markdown]
# ---
# ## US

# %%
df = investpy.indices.get_indices(country="united states")
df.head()
# Out:
#          country                                        name  \
# 0  united states                         NQ US Mid Cap Value
# 1  united states                        NQ US Mid Cap Growth
# 2  united states  NQ US Mid Cap Telecommunications Equipment
# 3  united states                NQ US Mid Cap Semiconductors
# 4  united states             NQ US Mid Cap Computer Hardware
#
#                                         full_name     symbol currency  \
# 0                         NASDAQ US Mid Cap Value     NQUSMV      USD
# 1                        NASDAQ US Mid Cap Growth     NQUSMG      USD
# 2  NASDAQ US Mid Cap Telecommunications Equipment  NQUSM9578      USD
# 3                NASDAQ US Mid Cap Semiconductors  NQUSM9576      USD
# 4             NASDAQ US Mid Cap Computer Hardware  NQUSM9572      USD
#
#            class          market
# 0  other_indices  global_indices
# 1  other_indices  global_indices
# 2  other_indices  global_indices
# 3  other_indices  global_indices
# ...

# %%
df[df.name.str.contains("S&P 500") & (df["class"]=="primary_sectors")]
# Out:
#            country                            name  \
# 387  united states  S&P 500 Consumer Discretionary
# 388  united states        S&P 500 Consumer Staples
# 408  united states                  S&P 500 Energy
# 409  united states              S&P 500 Financials
# 410  united states             S&P 500 Health Care
# 411  united states             S&P 500 Industrials
# 431  united states  S&P 500 Information Technology
# 432  united states               S&P 500 Materials
# 433  united states             S&P 500 Real Estate
# 434  united states        S&P 500 Telecom Services
# 435  united states               S&P 500 Utilities
#
#                           full_name    symbol currency            class  \
# 387  S&P 500 Consumer Discretionary    SPLRCD      USD  primary_sectors
# 388        S&P 500 Consumer Staples    SPLRCS      USD  primary_sectors
# 408                  S&P 500 Energy      SPNY      USD  primary_sectors
# ...

# %%
indice_name["US"] = df[df.name.str.contains("S&P 500") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %%
df = investpy.indices.get_index_historical_data(index="KOSPI 200 IT",
                                                country="south korea",
                                                from_date="01/07/2020",
                                                to_date="10/07/2020")

# %%
df
# Out:
#                Open     High      Low    Close    Volume Currency
# Date
# 2020-07-01  2387.98  2407.04  2361.58  2369.33  24144000      KRW
# 2020-07-02  2377.77  2384.82  2354.45  2377.45  21179000      KRW
# 2020-07-03  2400.23  2406.55  2383.14  2404.17  18441000      KRW
# 2020-07-06  2417.47  2460.81  2408.34  2455.63  34610000      KRW
# 2020-07-07  2484.51  2491.45  2416.06  2418.55  44669000      KRW
# 2020-07-08  2424.33  2440.83  2396.61  2401.07  29033000      KRW
# 2020-07-09  2410.68  2431.39  2401.25  2414.38  27784000      KRW
# 2020-07-10  2426.46  2429.57  2384.06  2404.12  23093000      KRW

# %% [markdown]
# ---
# ## JP

# %%
df = investpy.indices.get_indices(country="japan")
df.head()
# Out:
#   country                                    name  \
# 0   japan       TSE TOPIX17 Wholesale Stock Price
# 1   japan                             TOPIX Banks
# 2   japan  TSE TOPIX17 Transportation Stock Price
# 3   japan                TOPIX Air Transportation
# 4   japan           TSE TOPIX17 Steel Stock Price
#
#                                      full_name    symbol currency  \
# 0       Tokyo SE TOPIX17 Wholesale Stock Price  TRAD17.T      JPY
# 1                                  TOPIX Banks   IBNKS.T      JPY
# 2  Tokyo SE TOPIX17 Transportation Stock Price  TRAN17.T      JPY
# 3                     TOPIX Air Transportation   IAIRL.T      JPY
# 4           Tokyo SE TOPIX17 Steel Stock Price  STEL17.T      JPY
#
#              class         market
# 0  primary_sectors  world_indices
# 1  primary_sectors  world_indices
# 2  primary_sectors  world_indices
# 3  primary_sectors  world_indices
# 4  primary_sectors  world_indices

# %%
df[df.name.str.contains("TOPIX17") & (df["class"]=="primary_sectors")]
# Out:
#     country                                      name  \
# 0     japan         TSE TOPIX17 Wholesale Stock Price
# 2     japan    TSE TOPIX17 Transportation Stock Price
# 4     japan             TSE TOPIX17 Steel Stock Price
# 5     japan       TSE TOPIX17 IT Services Stock Price
# 6     japan       TSE TOPIX17 Real Estate Stock Price
# 7     japan         TSE TOPIX17 Power Gas Stock Price
# 8     japan     TSE TOPIX17 Pharmacetical Stock Price
# 9     japan         TSE TOPIX17 Machinery Stock Price
# 10    japan              TSE TOPIX17 Food Stock Price
# 12    japan            TSE TOPIX17 Retail Stock Price
# 58    japan        TSE TOPIX17 Financials Stock Price
# 198   japan  TSE TOPIX17 Energy Resources Stock Price
# 200   japan      TSE TOPIX17 Construction Stock Price
# 222   japan          TSE TOPIX17 Electric Stock Price
# 231   japan             TSE TOPIX17 Banks Stock Price
# 232   japan         TSE TOPIX17 Chemicals Stock Price
# ...

# %%
indice_name["JP"] = df[df.name.str.contains("TOPIX17") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %% [markdown]
# ---
# ## UK

# %%
df = investpy.indices.get_indices(country="united kingdom")
df.head()
# Out:
#           country                         name                    full_name  \
# 0  united kingdom    FTSE 100 Minimum Variance    FTSE 100 Minimum Variance
# 1  united kingdom  Stoxx UK 50 Risk 20% RV EUR  Stoxx UK 50 Risk 20% RV EUR
# 2  united kingdom  Stoxx UK 50 Risk 20% RV USD  Stoxx UK 50 Risk 20% RV USD
# 3  united kingdom  Stoxx UK 50 Risk 15% RV EUR  Stoxx UK 50 Risk 15% RV EUR
# 4  united kingdom  Stoxx UK 50 Risk 15% RV USD  Stoxx UK 50 Risk 15% RV USD
#
#      symbol currency          class          market
# 0   FTUKXMV      GBP  other_indices  global_indices
# 1  SUKR20EG      EUR  other_indices  global_indices
# 2  SUKR20DG      USD  other_indices  global_indices
# 3  SUKR15EG      EUR  other_indices  global_indices
# 4  SUKR15DG      USD  other_indices  global_indices

# %%
df[df.name.str.contains("FTSE 350") & (df["class"]=="primary_sectors")]
# Out:
#             country                                        name  \
# 73   united kingdom                              FTSE 350 REITs
# 76   united kingdom                        FTSE 350 Real Estate
# 82   united kingdom                     FTSE 350 Mobile Telecom
# 103  united kingdom      FTSE 350 Equity Investment Instruments
# 104  united kingdom  FTSE 350 Electronic & Electrical Equipment
# 105  united kingdom                        FTSE 350 Electricity
# 106  united kingdom  FTSE 350 Construction & Building Materials
# 107  united kingdom                          FTSE 350 Chemicals
# 108  united kingdom                          FTSE 350 Beverages
# 109  united kingdom                              FTSE 350 Banks
# 110  united kingdom                FTSE 350 Aerospace & Defense
# 133  united kingdom              FTSE 350 Industr Metals&Mining
# 134  united kingdom                     FTSE 350 Forestry&Paper
# 135  united kingdom                         FTSE 350 Auto&Parts
# ...

# %%
indice_name["UK"] = df[df.name.str.contains("FTSE 350") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %% [markdown]
# ---
# ## KS

# %%
df = investpy.indices.get_indices(country="south korea")
df.head()
# Out:
#        country                name           full_name    symbol currency  \
# 0  south korea      F-LKTB Inverse      F-LKTB Inverse  FLKTBINV      KRW
# 1  south korea        F-LKTB Index        F-LKTB Index     FLKTB      KRW
# 2  south korea       F-KTB Inverse       F-KTB Inverse   FKTBINV      KRW
# 3  south korea         F-KTB Index         F-KTB Index      FKTB      KRW
# 4  south korea  KRX Transportation  KRX Transportation  KRXTRANS      KRW
#
#            class         market
# 0  other_indices  world_indices
# 1  other_indices  world_indices
# 2  other_indices  world_indices
# 3  other_indices  world_indices
# 4  other_indices  world_indices

# %%
df[df.full_name.str.contains("KOSPI") & (df["class"]=="primary_sectors")]
# Out:
#          country                                 name  \
# 93   south korea                         KOSPI 200 IT
# 94   south korea           KOSPI 200 Heavy Industries
# 95   south korea                 KOSPI 200 Financials
# 96   south korea         KOSPI 200 Energy & Chemicals
# 97   south korea           KOSPI 200 Consumer Staples
# 98   south korea     KOSPI 200 Consumer Discretionary
# 100  south korea  KOSPI 200 Constructions & Machinery
# 114  south korea         KOSPI 200 Steels & Materials
#
#                                full_name     symbol currency            class  \
# 93                          KOSPI 200 IT    KS200IT      KRW  primary_sectors
# 94            KOSPI 200 Heavy Industries  KS200SHIP      KRW  primary_sectors
# 95                  KOSPI 200 Financials  KS200FNCL      KRW  primary_sectors
# 96          KOSPI 200 Energy & Chemicals  KS200ENER      KRW  primary_sectors
# 97            KOSPI 200 Consumer Staples  KS200CONS      KRW  primary_sectors
# ...

# %%
indice_name["KS"] = df[df.name.str.contains("KOSPI") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %% [markdown]
# ---
# ## DE

# %%
df = investpy.indices.get_indices(country="germany")
df.head()
# Out:
#    country                  name                         full_name  symbol  \
# 0  germany  Technology All Share          DAX Technology All Share  TECALL
# 1  germany   Pharma & Healthcare  DAX Pharmaceuticals & Healthcare   CXPPX
# 2  germany              Software                      DAX Software   CXPSX
# 3  germany            Technology                    DAX Technology   CXPHX
# 4  germany               Telecom                       DAX Telecom   CXPTX
#
#   currency               class         market
# 0      EUR  additional_indices  world_indices
# 1      EUR     primary_sectors  world_indices
# 2      EUR     primary_sectors  world_indices
# 3      EUR     primary_sectors  world_indices
# 4      EUR     primary_sectors  world_indices

# %%
df[df.full_name.str.contains("DAX") & (df["class"]=="primary_sectors")]
# Out:
#      country                   name                         full_name symbol  \
# 1    germany    Pharma & Healthcare  DAX Pharmaceuticals & Healthcare  CXPPX
# 2    germany               Software                      DAX Software  CXPSX
# 3    germany             Technology                    DAX Technology  CXPHX
# 4    germany                Telecom                       DAX Telecom  CXPTX
# 5    germany  Transport & Logistics    DAX Transportation & Logistics  CXPLX
# 8    germany                 Retail                        DAX Retail  CXPRX
# 80   germany                  Media                         DAX Media  CXPDX
# 109  germany              Insurance                     DAX Insurance  CXPIX
# 111  germany        Food & Beverage               DAX Food & Beverage  CXPFX
# 137  germany             Industrial                    DAX Industrial  CXPNX
# 155  germany              Utilities                     DAX Utilities  CXPUX
# ...

# %%
indice_name["DE"] = df[df.full_name.str.contains("DAX") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %% [markdown]
# ---
# ## AUD

# %%
df = investpy.indices.get_indices(country="australia")
df.head()
# Out:
#      country                             name  \
# 0  australia   S&P ASX Financials x a r Accum
# 1  australia                 SP/ASX 100 Accum
# 2  australia                  SP/ASX 20 Accum
# 3  australia  S&P/ASX 200 A Reit Equal Weight
# 4  australia         S&P/ASX 200 Equal Weight
#
#                               full_name symbol currency          class  \
# 0  S&P ASX Financials x a r Accumulated  AXXJA      AUD  other_indices
# 1               S&P/ASX 100 Accumulated  ATOIA      AUD  other_indices
# 2                S&P/ASX 20 Accumulated  ATLIA      AUD  other_indices
# 3       S&P/ASX 200 A Reit Equal Weight   AXAE      AUD  other_indices
# 4              S&P/ASX 200 Equal Weight   AXEW      AUD  other_indices
#
#           market
# 0  world_indices
# 1  world_indices
# 2  world_indices
# 3  world_indices
# 4  world_indices

# %%
df[df.full_name.str.contains("S&P/ASX 200") & (df["class"]=="primary_sectors")]
# Out:
#        country                                name  \
# 106  australia  S&P/ASX 200 Consumer Discretionary
# 107  australia        S&P/ASX 200 Consumer Staples
# 108  australia                  S&P/ASX 200 Energy
# 109  australia              S&P/ASX 200 Financials
# 110  australia             S&P/ASX 200 Health Care
# 111  australia             S&P/ASX 200 Industrials
# 112  australia  S&P/ASX 200 Information Technology
# 113  australia               S&P/ASX 200 Materials
# 114  australia                    S&P/ASX 200 REIT
# 115  australia               S&P/ASX 200 Resources
# 116  australia        S&P/ASX 200 Telecom Services
# 117  australia               S&P/ASX 200 Utilities
#
#                                   full_name symbol currency            class  \
# 106      S&P/ASX 200 Consumer Discretionary   AXDJ      AUD  primary_sectors
# 107            S&P/ASX 200 Consumer Staples   AXSJ      AUD  primary_sectors
# ...

# %%
indice_name["AU"] = df[df.full_name.str.contains("S&P/ASX 200") & (df["class"]=="primary_sectors")].full_name.values.tolist()

# %% [markdown]
# ---

# %%
indice_name
# Out:
# {'US': ['S&P 500 Consumer Discretionary',
#   'S&P 500 Consumer Staples',
#   'S&P 500 Energy',
#   'S&P 500 Financials',
#   'S&P 500 Health Care',
#   'S&P 500 Industrials',
#   'S&P 500 Information Technology',
#   'S&P 500 Materials',
#   'S&P 500 Real Estate',
#   'S&P 500 Telecom Services',
#   'S&P 500 Utilities'],
#  'JP': ['Tokyo SE TOPIX17 Wholesale Stock Price',
#   'Tokyo SE TOPIX17 Transportation Stock Price',
#   'Tokyo SE TOPIX17 Steel Stock Price',
#   'Tokyo SE TOPIX17 IT & Services Stock Price',
#   'Tokyo SE TOPIX17 Real Estate Stock Price',
#   'Tokyo SE TOPIX17 Power & Gas Stock Price',
#   'Tokyo SE TOPIX17 Pharmacetical Stock Price',
#   'Tokyo SE TOPIX17 Machinery Stock Price',
#   'Tokyo SE TOPIX17 Food Stock Price',
#   'Tokyo SE TOPIX17 Retail Stock Price',
#   'Tokyo SE TOPIX17 Financials Stock Price',
#   'Tokyo SE TOPIX17 Energy Resources Stock Price',
#   'Tokyo SE TOPIX17 Construction Stock Price',
#   'Tokyo SE TOPIX17 Electric Stock Price',
# ...

# %%
import yaml

# %%
config_yaml = {"invesing.com": {"Equity": {"Index": indice_name}}}

# %%
with open("test.yml", "w") as file:
    yaml.dump(config_yaml, file, indent=4)

# %%
with open("test.yml") as file:
    d = yaml.load(file)

# %%
with open("test.json", "w") as file:
    json.dump(d, file, indent=4)

# %% [markdown]
# ---
# ## Bond

# %%
investpy.bonds.get_bond_historical_data("Japan 1Y",
                                        from_date="01/07/2020",
                                        to_date="10/07/2020")
# Out:
#              Open   High    Low  Close
# Date
# 2020-07-01 -0.172 -0.169 -0.183 -0.169
# 2020-07-02 -0.165 -0.165 -0.183 -0.177
# 2020-07-03 -0.177 -0.174 -0.182 -0.182
# 2020-07-05 -0.174 -0.171 -0.174 -0.171
# 2020-07-06 -0.173 -0.169 -0.177 -0.170
# 2020-07-07 -0.170 -0.162 -0.172 -0.164
# 2020-07-08 -0.165 -0.163 -0.172 -0.163
# 2020-07-09 -0.163 -0.163 -0.177 -0.172
# 2020-07-10 -0.171 -0.169 -0.183 -0.171

# %%
bond_names = investpy.bonds.bonds_as_df()

# %%
bond_names.query("country == 'japan'").full_name.tolist()
# Out:
# ['Japan 7-Year',
#  'Japan 30-Year',
#  'Japan 20-Year',
#  'Japan 15-Year',
#  'Japan 10-Year',
#  'Japan 9-Year',
#  'Japan 8-Year',
#  'Japan 6-Year',
#  'Japan 40-Year',
#  'Japan 4-Year',
#  'Japan 3-Year',
#  'Japan 2-Year',
#  'Japan 1-Year',
#  'Japan 9-Month',
#  'Japan 6-Month',
#  'Japan 3-Month',
#  'Japan 1-Month',
#  'Japan 5-Year']

# %%
bond_names.query("country == 'united states'").full_name.tolist()
# Out:
# ['United States 30-Year',
#  'United States 10-Year',
#  'United States 7-Year',
#  'United States 5-Year',
#  'United States 3-Year',
#  'United States 3-Month',
#  'United States 1-Year',
#  'United States 6-Month',
#  'United States 1-Month',
#  'United States 2-Year']

# %%
bond_names.query("country == 'germany'").full_name.tolist()
# Out:
# ['Germany 10-Year',
#  'Germany 9-Year',
#  'Germany 15-Year',
#  'Germany 8-Year',
#  'Germany 25-Year',
#  'Germany 30-Year',
#  'Germany 20-Year',
#  'Germany 7-Year',
#  'Germany 1-Year',
#  'Germany 5-Year',
#  'Germany 4-Year',
#  'Germany 3-Year',
#  'Germany 2-Year',
#  'Germany 6-Year',
#  'Germany 9-Month',
#  'Germany 6-Month',
#  'Germany 3 Month']

# %%
bond_names.query("country == 'united kingdom'").full_name.tolist()
# Out:
# ['United Kingdom 40-Year',
#  'United Kingdom 50-Year',
#  'United Kingdom 30-Year',
#  'United Kingdom 25-Year',
#  'United Kingdom 15-Year',
#  'United Kingdom 12-Year',
#  'United Kingdom 10-Year',
#  'United Kingdom 9-Year',
#  'United Kingdom 8-Year',
#  'United Kingdom 20-Year',
#  'United Kingdom 6-Year',
#  'United Kingdom 5-Year',
#  'United Kingdom 4-Year',
#  'United Kingdom 3-Year',
#  'United Kingdom 2-Year',
#  'United Kingdom 1-Year',
#  'United Kingdom 6-Month',
#  'United Kingdom 3-Month',
#  'United Kingdom 1-Month',
#  'United Kingdom 7-Year']

# %% [markdown]
# ---

# %% [markdown]
# ### **Search

# %%
res = investpy.search(text="US Dollar Index")

# %%
len(res)
# Out:
# 15

# %%
[r for r in res if r.name == "US Dollar Index"]

# %%
res[0].country
# Out:
# 'united states'

# %%
res[0].pair_type
# Out:
# 'fxfuture'

# %%
res[0].retrieve_historical_data(
    from_date='01/01/1900',
    to_date=datetime.date.today().strftime("%m/%d/%Y")
)

# %% [markdown]
# ---

# %%
symbol = "Japan 7-Year"
search_res = investpy.search(text=symbol)
search_res = [r for r in search_res if r.name == symbol][0]

# %%
search_res

# %%
df = search_res.retrieve_historical_data(
    from_date='01/01/2020',
    to_date=datetime.date.today().strftime("02/01/2020")
)

# %%
df
# Out:
#              Open   High    Low  Close
# Date
# 2020-01-05 -0.111 -0.111 -0.132 -0.132
# 2020-01-06 -0.125 -0.114 -0.143 -0.118
# 2020-01-07 -0.101 -0.088 -0.106 -0.101
# 2020-01-08 -0.097 -0.095 -0.128 -0.108
# 2020-01-09 -0.078 -0.073 -0.097 -0.095
# 2020-01-10 -0.092 -0.084 -0.100 -0.090
# 2020-01-13 -0.095 -0.089 -0.095 -0.089
# 2020-01-14 -0.089 -0.065 -0.089 -0.069
# 2020-01-15 -0.080 -0.064 -0.083 -0.080
# 2020-01-16 -0.089 -0.078 -0.089 -0.084
# 2020-01-17 -0.074 -0.073 -0.093 -0.089
# 2020-01-19 -0.090 -0.090 -0.093 -0.093
# 2020-01-20 -0.085 -0.077 -0.095 -0.085
# 2020-01-21 -0.083 -0.074 -0.103 -0.101
# 2020-01-22 -0.096 -0.089 -0.104 -0.099
# 2020-01-23 -0.108 -0.104 -0.124 -0.120
# 2020-01-24 -0.118 -0.105 -0.125 -0.118
# 2020-01-26 -0.131 -0.131 -0.144 -0.144
# 2020-01-27 -0.145 -0.129 -0.148 -0.141
# 2020-01-28 -0.140 -0.128 -0.149 -0.135
# 2020-01-29 -0.125 -0.123 -0.137 -0.134
# 2020-01-30 -0.139 -0.139 -0.168 -0.157
# 2020-01-31 -0.154 -0.146 -0.167 -0.166
