# %% [markdown]
# optunaでtuningしたlgbmsをRFでensemble

# %%
import seaborn as sns
import csv
import optuna
import itertools, logging, joblib

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
NOTE_NAME = "lgbm2"

# %%
ROUND = "237"
TOURNAMENT_NAME = "kazutsugi"
TARGET_NAME = f"target_{TOURNAMENT_NAME}"
PREDICTION_NAME = f"prediction_{TOURNAMENT_NAME}"
N_FEATURE = 310

# %%
# Load Dataset
def read_csv(file_path):
    with open(file_path, 'r') as f:
        column_names = next(csv.reader(f))
    dtypes = {x: np.float16 for x in column_names if x.startswith(('feature', 'target'))}
    df = pd.read_csv(file_path, dtype=dtypes, index_col=0)
    return df

train = read_csv("../../dataset/numerai_dataset_237/numerai_training_data.csv")
tournament = read_csv("../../dataset/numerai_dataset_237/numerai_tournament_data.csv")

# reform
train.sort_index(axis=1, inplace=True)
tournament.sort_index(axis=1, inplace=True)
cols_feature = train.columns[train.columns.str.contains("feature_")]
cols_target  = train.columns[train.columns.str.contains("target_")]

# %%
train.head(1).append(tournament.tail(1))
# Out:
#                  data_type   era  feature_charisma1  feature_charisma10  \
# id
# n000315175b67977     train  era1               1.00                 0.0
# nfffd2286c1361bd      live  eraX               0.25                 1.0
#
#                   feature_charisma11  feature_charisma12  feature_charisma13  \
# id
# n000315175b67977                0.00                1.00                0.25
# nfffd2286c1361bd                0.25                0.75                1.00
#
#                   feature_charisma14  feature_charisma15  feature_charisma16  \
# id
# n000315175b67977                0.00                0.50                0.25
# nfffd2286c1361bd                0.75                0.25                0.50
#
#                   feature_charisma17  feature_charisma18  feature_charisma19  \
# id
# n000315175b67977                0.75                 0.5                1.00
# nfffd2286c1361bd                1.00                 0.5                0.25
#
#                   feature_charisma2  feature_charisma20  feature_charisma21  \
# id
# n000315175b67977               0.75                0.75                0.75
# nfffd2286c1361bd               0.25                1.00                0.25
#
#                   feature_charisma22  feature_charisma23  feature_charisma24  \
# id
# n000315175b67977                 0.5                0.50                0.75
# nfffd2286c1361bd                 1.0                0.25                0.25
#
#                   feature_charisma25  feature_charisma26  feature_charisma27  \
# id
# n000315175b67977                0.50                0.25                0.75
# nfffd2286c1361bd                0.75                0.75                0.50
#
#                   feature_charisma28  feature_charisma29  feature_charisma3  \
# id
# n000315175b67977                0.75                 0.5               0.50
# nfffd2286c1361bd                0.25                 0.5               0.75
#
#                   feature_charisma30  feature_charisma31  feature_charisma32  \
# id
# n000315175b67977                0.25                0.25                 0.5
# nfffd2286c1361bd                0.75                0.75                 1.0
#
#                   feature_charisma33  feature_charisma34  feature_charisma35  \
# id
# n000315175b67977                0.25                 0.5                0.25
# nfffd2286c1361bd                0.75                 1.0                0.75
#
#                   feature_charisma36  feature_charisma37  feature_charisma38  \
# id
# n000315175b67977                0.75                0.25                0.25
# nfffd2286c1361bd                0.25                0.25                0.75
#
#                   feature_charisma39  feature_charisma4  feature_charisma40  \
# id
# n000315175b67977                0.50                1.0                0.50
# nfffd2286c1361bd                0.25                1.0                0.75
#
#                   feature_charisma41  feature_charisma42  feature_charisma43  \
# id
# n000315175b67977                0.75                0.25                0.50
# nfffd2286c1361bd                0.50                0.75                0.25
#
#                   feature_charisma44  feature_charisma45  feature_charisma46  \
# id
# n000315175b67977                0.25                 0.5                0.25
# nfffd2286c1361bd                0.50                 0.5                0.75
#
#                   feature_charisma47  feature_charisma48  feature_charisma49  \
# id
# n000315175b67977                0.50                 0.5                0.50
# nfffd2286c1361bd                0.75                 1.0                0.75
#
#                   feature_charisma5  feature_charisma50  feature_charisma51  \
# id
# n000315175b67977               0.50                0.25                 0.5
# nfffd2286c1361bd               0.25                1.00                 0.5
#
#                   feature_charisma52  feature_charisma53  feature_charisma54  \
# id
# n000315175b67977                0.25                0.75                0.00
# nfffd2286c1361bd                0.50                0.25                0.75
#
#                   feature_charisma55  feature_charisma56  feature_charisma57  \
# id
# n000315175b67977                0.25                 0.5                0.00
# nfffd2286c1361bd                0.75                 0.5                0.75
#
#                   feature_charisma58  feature_charisma59  feature_charisma6  \
# id
# n000315175b67977                0.00                0.75                0.0
# nfffd2286c1361bd                0.25                0.50                1.0
#
#                   feature_charisma60  feature_charisma61  feature_charisma62  \
# id
# n000315175b67977                0.50                0.50                0.25
# nfffd2286c1361bd                0.75                0.75                0.50
#
#                   feature_charisma63  feature_charisma64  feature_charisma65  \
# id
# n000315175b67977                0.50                 0.5                0.50
# nfffd2286c1361bd                0.25                 1.0                0.75
#
#                   feature_charisma66  feature_charisma67  feature_charisma68  \
# id
# n000315175b67977                0.25                0.25                0.25
# nfffd2286c1361bd                0.75                0.50                0.00
#
#                   feature_charisma69  feature_charisma7  feature_charisma70  \
# id
# n000315175b67977                0.00               0.50                 0.5
# nfffd2286c1361bd                0.75               0.75                 0.5
#
#                   feature_charisma71  feature_charisma72  feature_charisma73  \
# id
# n000315175b67977                0.50                 0.5                0.50
# nfffd2286c1361bd                0.75                 0.5                0.75
#
#                   feature_charisma74  feature_charisma75  feature_charisma76  \
# id
# n000315175b67977                 0.0                 0.5                0.50
# nfffd2286c1361bd                 0.5                 0.5                0.75
#
#                   feature_charisma77  feature_charisma78  feature_charisma79  \
# id
# n000315175b67977                0.75                 0.0                 0.5
# nfffd2286c1361bd                0.50                 1.0                 0.5
#
#                   feature_charisma8  feature_charisma80  feature_charisma81  \
# id
# n000315175b67977               0.50                0.75                0.50
# nfffd2286c1361bd               0.25                0.50                0.75
#
#                   feature_charisma82  feature_charisma83  feature_charisma84  \
# id
# n000315175b67977                 0.5                0.00                0.75
# nfffd2286c1361bd                 0.0                0.75                0.50
#
#                   feature_charisma85  feature_charisma86  feature_charisma9  \
# id
# n000315175b67977                 0.5                0.50               0.00
# nfffd2286c1361bd                 0.5                0.75               0.75
#
#                   feature_constitution1  feature_constitution10  \
# id
# n000315175b67977                   0.25                    0.25
# nfffd2286c1361bd                   0.00                    0.75
#
#                   feature_constitution100  feature_constitution101  \
# id
# n000315175b67977                     0.75                      0.5
# nfffd2286c1361bd                     0.75                      0.0
#
#                   feature_constitution102  feature_constitution103  \
# id
# n000315175b67977                     0.50                     0.25
# nfffd2286c1361bd                     0.75                     0.50
#
#                   feature_constitution104  feature_constitution105  \
# id
# n000315175b67977                     1.00                     0.75
# nfffd2286c1361bd                     0.75                     0.75
#
#                   feature_constitution106  feature_constitution107  \
# id
# n000315175b67977                     0.25                     0.25
# nfffd2286c1361bd                     0.75                     0.75
#
#                   feature_constitution108  feature_constitution109  \
# id
# n000315175b67977                     0.50                     0.50
# nfffd2286c1361bd                     0.75                     0.75
#
#                   feature_constitution11  feature_constitution110  \
# id
# n000315175b67977                    0.75                     0.25
# nfffd2286c1361bd                    0.75                     0.75
#
#                   feature_constitution111  feature_constitution112  \
# id
# n000315175b67977                     0.25                     0.50
# nfffd2286c1361bd                     0.75                     0.75
#
#                   feature_constitution113  feature_constitution114  \
# id
# n000315175b67977                     0.50                     0.25
# nfffd2286c1361bd                     0.75                     0.75
#
#                   feature_constitution12  feature_constitution13  \
# id
# n000315175b67977                    0.50                    0.50
# nfffd2286c1361bd                    0.25                    0.75
#
#                   feature_constitution14  feature_constitution15  \
# id
# n000315175b67977                    0.50                    0.00
# nfffd2286c1361bd                    0.25                    0.25
#
#                   feature_constitution16  feature_constitution17  \
# id
# n000315175b67977                     1.0                    0.75
# nfffd2286c1361bd                     0.5                    0.25
#
#                   feature_constitution18  feature_constitution19  \
# id
# n000315175b67977                    0.25                    0.75
# nfffd2286c1361bd                    0.50                    1.00
#
#                   feature_constitution2  feature_constitution20  \
# id
# n000315175b67977                    0.5                    0.25
# nfffd2286c1361bd                    1.0                    0.00
#
#                   feature_constitution21  feature_constitution22  \
# id
# n000315175b67977                    0.75                    0.00
# nfffd2286c1361bd                    0.25                    0.75
#
#                   feature_constitution23  feature_constitution24  \
# id
# n000315175b67977                     0.5                    0.00
# nfffd2286c1361bd                     0.0                    0.25
#
#                   feature_constitution25  feature_constitution26  \
# id
# n000315175b67977                    0.25                     0.5
# nfffd2286c1361bd                    0.75                     0.0
#
#                   feature_constitution27  feature_constitution28  \
# id
# n000315175b67977                    0.25                    0.50
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_constitution29  feature_constitution3  \
# id
# n000315175b67977                    0.25                   0.50
# nfffd2286c1361bd                    0.25                   0.25
#
#                   feature_constitution30  feature_constitution31  \
# id
# n000315175b67977                    0.50                     1.0
# nfffd2286c1361bd                    0.25                     1.0
#
#                   feature_constitution32  feature_constitution33  \
# id
# n000315175b67977                    0.00                    0.25
# nfffd2286c1361bd                    0.75                    0.25
#
#                   feature_constitution34  feature_constitution35  \
# id
# n000315175b67977                     0.5                    0.75
# nfffd2286c1361bd                     1.0                    0.75
#
#                   feature_constitution36  feature_constitution37  \
# id
# n000315175b67977                     0.5                    0.25
# nfffd2286c1361bd                     1.0                    0.25
#
#                   feature_constitution38  feature_constitution39  \
# id
# n000315175b67977                    0.00                    0.25
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_constitution4  feature_constitution40  \
# id
# n000315175b67977                   0.75                    0.75
# nfffd2286c1361bd                   0.75                    0.75
#
#                   feature_constitution41  feature_constitution42  \
# id
# n000315175b67977                    0.50                    0.25
# nfffd2286c1361bd                    0.75                    0.25
#
#                   feature_constitution43  feature_constitution44  \
# id
# n000315175b67977                    0.25                     0.5
# nfffd2286c1361bd                    0.00                     0.0
#
#                   feature_constitution45  feature_constitution46  \
# id
# n000315175b67977                     0.5                    0.75
# nfffd2286c1361bd                     1.0                    0.75
#
#                   feature_constitution47  feature_constitution48  \
# id
# n000315175b67977                    0.75                    0.00
# nfffd2286c1361bd                    1.00                    0.75
#
#                   feature_constitution49  feature_constitution5  \
# id
# n000315175b67977                    0.50                   0.00
# nfffd2286c1361bd                    0.75                   0.75
#
#                   feature_constitution50  feature_constitution51  \
# id
# n000315175b67977                    0.25                    0.50
# nfffd2286c1361bd                    0.00                    0.25
#
#                   feature_constitution52  feature_constitution53  \
# id
# n000315175b67977                     0.0                     0.5
# nfffd2286c1361bd                     0.5                     1.0
#
#                   feature_constitution54  feature_constitution55  \
# id
# n000315175b67977                     1.0                     0.5
# nfffd2286c1361bd                     1.0                     0.0
#
#                   feature_constitution56  feature_constitution57  \
# id
# n000315175b67977                    0.50                    0.00
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_constitution58  feature_constitution59  \
# id
# n000315175b67977                    1.00                    0.25
# nfffd2286c1361bd                    0.75                    0.25
#
#                   feature_constitution6  feature_constitution60  \
# id
# n000315175b67977                    0.0                     0.5
# nfffd2286c1361bd                    1.0                     0.5
#
#                   feature_constitution61  feature_constitution62  \
# id
# n000315175b67977                     0.5                    0.25
# nfffd2286c1361bd                     0.0                    0.00
#
#                   feature_constitution63  feature_constitution64  \
# id
# n000315175b67977                    0.50                    0.75
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_constitution65  feature_constitution66  \
# id
# n000315175b67977                    0.00                     0.5
# nfffd2286c1361bd                    0.75                     0.0
#
#                   feature_constitution67  feature_constitution68  \
# id
# n000315175b67977                    0.25                     1.0
# nfffd2286c1361bd                    0.75                     0.5
#
#                   feature_constitution69  feature_constitution7  \
# id
# n000315175b67977                    0.25                   0.50
# nfffd2286c1361bd                    0.50                   0.75
#
#                   feature_constitution70  feature_constitution71  \
# id
# n000315175b67977                    0.75                     0.5
# nfffd2286c1361bd                    0.25                     1.0
#
#                   feature_constitution72  feature_constitution73  \
# id
# n000315175b67977                    0.25                    0.25
# nfffd2286c1361bd                    0.50                    0.75
#
#                   feature_constitution74  feature_constitution75  \
# id
# n000315175b67977                    0.00                    0.00
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_constitution76  feature_constitution77  \
# id
# n000315175b67977                    0.75                     0.0
# nfffd2286c1361bd                    0.00                     1.0
#
#                   feature_constitution78  feature_constitution79  \
# id
# n000315175b67977                     0.5                    0.25
# nfffd2286c1361bd                     1.0                    0.75
#
#                   feature_constitution8  feature_constitution80  \
# id
# n000315175b67977                   0.75                    0.25
# nfffd2286c1361bd                   0.00                    0.00
#
#                   feature_constitution81  feature_constitution82  \
# id
# n000315175b67977                    0.25                    0.25
# nfffd2286c1361bd                    0.25                    0.25
#
#                   feature_constitution83  feature_constitution84  \
# id
# n000315175b67977                    1.00                    0.25
# nfffd2286c1361bd                    0.25                    0.00
#
#                   feature_constitution85  feature_constitution86  \
# id
# n000315175b67977                     0.5                     0.0
# nfffd2286c1361bd                     0.0                     0.0
#
#                   feature_constitution87  feature_constitution88  \
# id
# n000315175b67977                     0.5                    0.75
# nfffd2286c1361bd                     0.5                    1.00
#
#                   feature_constitution89  feature_constitution9  \
# id
# n000315175b67977                    0.50                   0.25
# nfffd2286c1361bd                    0.25                   0.25
#
#                   feature_constitution90  feature_constitution91  \
# id
# n000315175b67977                    0.75                    0.25
# nfffd2286c1361bd                    1.00                    0.75
#
#                   feature_constitution92  feature_constitution93  \
# id
# n000315175b67977                     0.5                     0.5
# nfffd2286c1361bd                     0.5                     0.0
#
#                   feature_constitution94  feature_constitution95  \
# id
# n000315175b67977                     0.0                     1.0
# nfffd2286c1361bd                     0.0                     1.0
#
#                   feature_constitution96  feature_constitution97  \
# id
# n000315175b67977                    0.25                    0.25
# nfffd2286c1361bd                    0.25                    0.75
#
#                   feature_constitution98  feature_constitution99  \
# id
# n000315175b67977                    0.50                    0.50
# nfffd2286c1361bd                    0.75                    0.75
#
#                   feature_dexterity1  feature_dexterity10  \
# id
# n000315175b67977                0.75                 0.75
# nfffd2286c1361bd                0.75                 0.75
#
#                   feature_dexterity11  feature_dexterity12  \
# id
# n000315175b67977                 0.75                 0.25
# nfffd2286c1361bd                 0.50                 0.50
#
#                   feature_dexterity13  feature_dexterity14  \
# id
# n000315175b67977                 0.75                 0.50
# nfffd2286c1361bd                 0.50                 0.25
#
#                   feature_dexterity2  feature_dexterity3  feature_dexterity4  \
# id
# n000315175b67977                0.75                0.50                 1.0
# nfffd2286c1361bd                0.75                0.25                 0.5
#
#                   feature_dexterity5  feature_dexterity6  feature_dexterity7  \
# id
# n000315175b67977                0.75                0.75                1.00
# nfffd2286c1361bd                0.50                0.75                0.25
#
#                   feature_dexterity8  feature_dexterity9  \
# id
# n000315175b67977                 0.5                0.75
# nfffd2286c1361bd                 0.5                0.50
#
#                   feature_intelligence1  feature_intelligence10  \
# id
# n000315175b67977                   0.00                    0.75
# nfffd2286c1361bd                   0.25                    0.75
#
#                   feature_intelligence11  feature_intelligence12  \
# id
# n000315175b67977                    0.25                    0.25
# nfffd2286c1361bd                    0.00                    0.75
#
#                   feature_intelligence2  feature_intelligence3  \
# id
# n000315175b67977                    0.5                   0.25
# nfffd2286c1361bd                    0.5                   0.50
#
#                   feature_intelligence4  feature_intelligence5  \
# id
# n000315175b67977                   0.00                    0.5
# nfffd2286c1361bd                   0.25                    1.0
#
#                   feature_intelligence6  feature_intelligence7  \
# id
# n000315175b67977                   0.25                   0.25
# nfffd2286c1361bd                   0.50                   0.50
#
#                   feature_intelligence8  feature_intelligence9  \
# id
# n000315175b67977                   0.25                   0.75
# nfffd2286c1361bd                   0.25                   0.75
#
#                   feature_strength1  feature_strength10  feature_strength11  \
# id
# n000315175b67977                0.0                 0.5                 0.0
# nfffd2286c1361bd                0.5                 0.5                 0.5
#
#                   feature_strength12  feature_strength13  feature_strength14  \
# id
# n000315175b67977                0.50                0.75                 0.5
# nfffd2286c1361bd                0.75                1.00                 0.5
#
#                   feature_strength15  feature_strength16  feature_strength17  \
# id
# n000315175b67977                0.00                0.75                 0.5
# nfffd2286c1361bd                0.75                0.75                 1.0
#
#                   feature_strength18  feature_strength19  feature_strength2  \
# id
# n000315175b67977                0.75                0.00               0.75
# nfffd2286c1361bd                0.25                0.25               0.50
#
#                   feature_strength20  feature_strength21  feature_strength22  \
# id
# n000315175b67977                 0.5                0.00                0.75
# nfffd2286c1361bd                 0.5                0.25                0.50
#
#                   feature_strength23  feature_strength24  feature_strength25  \
# id
# n000315175b67977                0.75                0.25                0.50
# nfffd2286c1361bd                0.50                0.75                0.25
#
#                   feature_strength26  feature_strength27  feature_strength28  \
# id
# n000315175b67977                 0.5                0.00                1.00
# nfffd2286c1361bd                 0.5                0.75                0.75
#
#                   feature_strength29  feature_strength3  feature_strength30  \
# id
# n000315175b67977                0.25                0.0                 0.5
# nfffd2286c1361bd                1.00                0.0                 0.5
#
#                   feature_strength31  feature_strength32  feature_strength33  \
# id
# n000315175b67977                0.75                0.75                 0.5
# nfffd2286c1361bd                0.25                0.25                 0.5
#
#                   feature_strength34  feature_strength35  feature_strength36  \
# id
# n000315175b67977                0.75                 0.5                0.50
# nfffd2286c1361bd                0.50                 0.5                0.25
#
#                   feature_strength37  feature_strength38  feature_strength4  \
# id
# n000315175b67977                 0.5                 0.5               0.25
# nfffd2286c1361bd                 0.5                 0.5               0.25
#
#                   feature_strength5  feature_strength6  feature_strength7  \
# id
# n000315175b67977               0.75               0.25                0.5
# nfffd2286c1361bd               1.00               1.00                0.5
#
#                   feature_strength8  feature_strength9  feature_wisdom1  \
# id
# n000315175b67977               1.00               0.75             0.25
# nfffd2286c1361bd               0.75               0.75             1.00
#
#                   feature_wisdom10  feature_wisdom11  feature_wisdom12  \
# id
# n000315175b67977              0.75              0.50               1.0
# nfffd2286c1361bd              1.00              0.25               1.0
#
#                   feature_wisdom13  feature_wisdom14  feature_wisdom15  \
# id
# n000315175b67977               1.0               0.5              0.75
# nfffd2286c1361bd               1.0               1.0              1.00
#
#                   feature_wisdom16  feature_wisdom17  feature_wisdom18  \
# id
# n000315175b67977               0.5              0.25              0.25
# nfffd2286c1361bd               1.0              0.75              0.25
#
#                   feature_wisdom19  feature_wisdom2  feature_wisdom20  \
# id
# n000315175b67977              0.75              1.0               0.5
# nfffd2286c1361bd              1.00              1.0               1.0
#
#                   feature_wisdom21  feature_wisdom22  feature_wisdom23  \
# id
# n000315175b67977              1.00              0.50              0.75
# nfffd2286c1361bd              0.75              0.75              1.00
#
#                   feature_wisdom24  feature_wisdom25  feature_wisdom26  \
# id
# n000315175b67977              0.75              0.25              0.50
# nfffd2286c1361bd              0.75              0.25              0.25
#
#                   feature_wisdom27  feature_wisdom28  feature_wisdom29  \
# id
# n000315175b67977               1.0              0.75              0.50
# nfffd2286c1361bd               1.0              0.75              0.75
#
#                   feature_wisdom3  feature_wisdom30  feature_wisdom31  \
# id
# n000315175b67977             0.75               0.5              1.00
# nfffd2286c1361bd             0.75               1.0              0.75
#
#                   feature_wisdom32  feature_wisdom33  feature_wisdom34  \
# id
# n000315175b67977              0.25               0.5               0.5
# nfffd2286c1361bd              1.00               0.5               1.0
#
#                   feature_wisdom35  feature_wisdom36  feature_wisdom37  \
# id
# n000315175b67977              0.50              0.75              1.00
# nfffd2286c1361bd              0.75              0.75              0.75
#
#                   feature_wisdom38  feature_wisdom39  feature_wisdom4  \
# id
# n000315175b67977              1.00              1.00              0.5
# nfffd2286c1361bd              0.75              0.75              1.0
#
#                   feature_wisdom40  feature_wisdom41  feature_wisdom42  \
# id
# n000315175b67977              0.75               0.5              0.75
# nfffd2286c1361bd              0.00               0.0              0.75
#
#                   feature_wisdom43  feature_wisdom44  feature_wisdom45  \
# id
# n000315175b67977               0.5              1.00               0.5
# nfffd2286c1361bd               0.5              0.25               1.0
#
#                   feature_wisdom46  feature_wisdom5  feature_wisdom6  \
# id
# n000315175b67977              0.75             0.75             0.75
# nfffd2286c1361bd              1.00             0.25             0.25
#
#                   feature_wisdom7  feature_wisdom8  feature_wisdom9  \
# id
# n000315175b67977             0.75             0.75             0.75
# nfffd2286c1361bd             1.00             0.50             0.75
#
#                   target_kazutsugi
# id
# n000315175b67977              0.75
# nfffd2286c1361bd               NaN

# %%
# signal
signals = pd.read_csv(f"{NOTE_NAME}/lgbm2_signals_train.csv", index_col=["id"])
val_signals = pd.read_csv(f"{NOTE_NAME}/lgbm2_signals_val.csv", index_col=["id"])

# %%
signals.head(1)
# Out:
#                          0         1         2         3         4       5  \
# id
# n000315175b67977  0.480082  0.497053  0.490263  0.495587  0.501191  0.4956
#
#                    era  target_kazutsugi  eraNum
# id
# n000315175b67977  era1              0.75       1

# %% [markdown]
# ---
# ### Fit RFReg

# %%
# train signal data
X_train = signals.iloc[:, :6].values
y_train = signals[TARGET_NAME].values
X_val = val_signals.dropna().iloc[:, :6].values
y_val = val_signals.dropna()[TARGET_NAME].values

# %%
def objective(trial):
    max_depth = trial.suggest_int("max_depth", 3, 29, 2)
    min_samples_leaf = trial.suggest_uniform("min_samples_leaf", 0.01, 0.50)
    reg = RandomForestRegressor(
        criterion="mse",
        max_features=None,
        max_depth=max_depth, 
        min_samples_leaf=min_samples_leaf)
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_val)
    mse = mean_squared_error(y_val, y_pred)
    return mse

# %%
# set logger
logger = logging.getLogger()  # root logger
fh = logging.FileHandler(f'{NOTE_NAME}/train3.log')
fh.setFormatter(logging.Formatter('%(asctime)s|%(message)s', '%Y-%m-%d %H:%M:%S'))
logger.addHandler(fh)

optuna.logging.enable_propagation()  # Propagate logs to the root logger.
optuna.logging.disable_default_handler()  # Stop showing logs in sys.stderr.

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=100)

# %% [markdown]
# -----
# ## 各モデルのFeatureImportance, FeatureExposure

# %%
from scipy.stats import spearmanr
def calcFeatureExposure(X:pd.DataFrame, pred:np.ndarray)->pd.Series:
    # pred: np.array
    exposures = [spearmanr(pred, X[col])[0] for col in X.columns]
    return pd.Series(exposures, index=X.columns)

# %% [markdown]
# - FeatureImportance
# - FeatureExposure
